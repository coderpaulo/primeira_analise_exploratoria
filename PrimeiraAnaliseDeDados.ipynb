# %% [markdown]
# <a href="https://colab.research.google.com/github/coderpaulo/primeira_analise_exploratoria/blob/main/PrimeiraAnaliseDeDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('vgsales.csv')
data.columns= data.columns .str.capitalize()
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  Na_sales  Eu_sales  Jp_sales  \
# ...

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    Na_sales  Eu_sales  Jp_sales  Other_sales  Global_sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.columns = ['Rank', 'Nome', 'Plataforma', 'Ano', 'Genêro', 'Editora', 'Vendas_America_do_Norte_Vendas',
       'Vendas_Europa', 'Vendas_Japão', 'Outras_Vendas', 'Vendas_Globais']
data.head()
# Out:
#    Rank                      Nome Plataforma     Ano        Genêro   Editora  \
# 0     1                Wii Sports        Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.        NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii        Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort        Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing  Nintendo
#
#    Vendas_America_do_Norte_Vendas  Vendas_Europa  Vendas_Japão  Outras_Vendas  \
# 0                           41.49          29.02          3.77           8.46
# 1                           29.08           3.58          6.81           0.77
# 2                           15.85          12.88          3.79           3.31
# 3                           15.75          11.01          3.28           2.96
# 4                           11.27           8.89         10.22           1.00
#
#    Vendas_Globais
# ...

# %%
data.shape
# Out:
# (16598, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            16598 non-null  int64
#  1   Nome                            16598 non-null  object
#  2   Plataforma                      16598 non-null  object
#  3   Ano                             16327 non-null  float64
#  4   Genêro                          16598 non-null  object
#  5   Editora                         16540 non-null  object
#  6   Vendas_America_do_Norte_Vendas  16598 non-null  float64
#  7   Vendas_Europa                   16598 non-null  float64
#  8   Vendas_Japão                    16598 non-null  float64
#  9   Outras_Vendas                   16598 non-null  float64
#  10  Vendas_Globais                  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
data.isnull().sum()
# Out:
# Rank                                0
# Nome                                0
# Plataforma                          0
# Ano                               271
# Genêro                              0
# Editora                            58
# Vendas_America_do_Norte_Vendas      0
# Vendas_Europa                       0
# Vendas_Japão                        0
# Outras_Vendas                       0
# Vendas_Globais                      0
# dtype: int64

# %%
data.dropna(inplace=True)         #excluindo valores nulos.
data.shape[0]
# Out:
# 16291

# %%
data['Ano']=data['Ano'].astype(int)     #convertendo de float para int

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()
# Out:
# Rank                              16291
# Nome                              11325
# Plataforma                           31
# Ano                                  39
# Genêro                               12
# Editora                             576
# Vendas_America_do_Norte_Vendas      408
# Vendas_Europa                       305
# Vendas_Japão                        244
# Outras_Vendas                       157
# Vendas_Globais                      621
# dtype: int64

# %%
data.describe()
# Out:
#                Rank           Ano  Vendas_America_do_Norte_Vendas  \
# count  16291.000000  16291.000000                    16291.000000
# mean    8290.190228   2006.405561                        0.265647
# std     4792.654450      5.832412                        0.822432
# min        1.000000   1980.000000                        0.000000
# 25%     4132.500000   2003.000000                        0.000000
# 50%     8292.000000   2007.000000                        0.080000
# 75%    12439.500000   2010.000000                        0.240000
# max    16600.000000   2020.000000                       41.490000
#
#        Vendas_Europa  Vendas_Japão  Outras_Vendas  Vendas_Globais
# count   16291.000000  16291.000000   16291.000000    16291.000000
# mean        0.147731      0.078833       0.048426        0.540910
# std         0.509303      0.311879       0.190083        1.567345
# min         0.000000      0.000000       0.000000        0.010000
# ...

# %% [markdown]
# # Explorando analise de dados sobre vendas:

# %% [markdown]
#  Qual genêro tem maior numero de jogo?

# %%
data['Genêro'].value_counts()
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genêro, dtype: int64

# %%
bars = data.Genêro.value_counts()
bars.plot(kind="bar",title='Top Genres',figsize=(8,5))
plt.show()

# %% [markdown]
# Encontrando os jogos lançados em ordem decrescente de anos:

# %%
plt.figure(figsize=(8, 5))  # Configura o tamanho da figura do gráfico

# Cria um gráfico de contagem (countplot) com o eixo x sendo os anos e os dados vindo do DataFrame data
sns.countplot(x="Ano", data=data, order=data.groupby(by=['Ano'])['Nome'].count().sort_values(ascending=False).index)

plt.xticks(rotation='vertical')  # Rotaciona os rótulos do eixo x para que sejam legíveis
plt.title('Jogos Lançados por Ano')  # Define o título do gráfico
plt.ylabel('Contagem')  # Define o rótulo do eixo y como "Contagem"
plt.xlabel('Ano')  # Define o rótulo do eixo x como "Ano"

plt.show()  # Exibe o gráfico

# %% [markdown]
# Analise de vendas por região:

# %%
região = ['Vendas_America_do_Norte_Vendas', 'Vendas_Europa', 'Vendas_Japão', 'Outras_Vendas']
vendas_por_região = data[região].sum()

# %%
plt.figure(figsize=(10, 6))
vendas_por_região.plot(kind='bar', color=['blue', 'green', 'red', 'orange'])
plt.xlabel('Região')
plt.ylabel('Total de vendas (em milhões)')
plt.title('Total de vendas por região')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Qual ano tem maior numero de vendas no mundo todo?

# %%
vendas_por_ano = data.groupby('Ano')['Vendas_Globais'].sum()
ano_de_maior_venda = vendas_por_ano.idxmax()
print(ano_de_maior_venda)
# Out:
# 2008

# %%
ano_vendas_de_video_games = data.groupby('Ano')[['Vendas_Globais','Vendas_America_do_Norte_Vendas','Vendas_Europa','Vendas_Japão','Outras_Vendas']].sum()
ano_vendas_de_video_games.plot(figsize = (12,8))
plt.axvline(x=ano_de_maior_venda ,c = 'black',linestyle = '-.',alpha = 0.6)
plt.ylabel('Vendas (milhões de dolares)',fontsize = 12)
plt.show()

# %% [markdown]
# Os videogames experimentaram um aumento significativo em sua popularidade a partir de 2008-2009, especialmente no gênero de ação, seguido por esportes. A América do Norte, em particular, liderou em termos de vendas em comparação com outras regiões.
#
# Esta análise contribui para uma melhor compreensão do mercado de videogames e destaca a importância de acompanhar sua evolução e identificar áreas que ainda necessitam de aprimoramento.
